# %%
# Load libraries
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df = pd.read_csv("technology-df.csv")
df.head()
# Out:
#    Unnamed: 0                              index  \
# 0           0  Ink helps drive democracy in Asia
# 1           1   China net cafe culture crackdown
# 2           2   Microsoft seeking spyware trojan
# 3           3    Digital guru floats sub-$100 PC
# 4           4   Technology gets the creative bug
#
#                                                    0  \
# 0  The Kyrgyz Republic, a small, mountainous stat...
# 1  Chinese authorities closed 12,575 net cafes in...
# 2  Microsoft is investigating a trojan program th...
# 3  Nicholas Negroponte, chairman and founder of M...
# 4  The hi-tech and the arts worlds have for some ...
#
#                                                    1  \
# 0  This new technology is causing both worries an...
# 1  According to the official news agency most of ...
# 2  The spyware tool was only released by Microsof...
# 3  He told the BBC World Service programme Go Dig...
# 4  Often this help has come in the form of corpor...
#
#                                                    2  \
# 0  The Kyrgyz Republic is seen by many experts as...
# 1  The official Xinhua News Agency said the crack...
# 2  It may also try to steal online banking passwo...
# 3  The second trick is to get rid of the fat , if...
# 4  To mark the initiative's launch, a major inter...
#
#                                                    3  \
# 0  The actual technology behind the ink is not th...
# 1  Net cafes are hugely popular in China because ...
# 2  Microsoft said in a statement it is investigat...
# 3  While the idea was popular amongst the childre...
# 4  They have recently been excavated and are thou...
#
#                                                    4  \
# 0  However, the presence of ultraviolet light (of...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  As more tools for self-expression are given to...
#
#                                                    5  \
# 0  Widely circulated articles compared the use of...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Technology as a way of unleashing creativity h...
#
#                                                    6  \
# 0  The author of one such article began a petitio...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    7  ...   37   38   39   40  \
# 0  In Serbia, for example, both Christian and Isl...  ...  NaN  NaN  NaN  NaN
# 1                                                NaN  ...  NaN  NaN  NaN  NaN
# 2                                                NaN  ...  NaN  NaN  NaN  NaN
# 3                                                NaN  ...  NaN  NaN  NaN  NaN
# 4                                                NaN  ...  NaN  NaN  NaN  NaN
#
#     41   42 index_score desc1_score desc2_score label
# 0  NaN  NaN      0.3818      0.0258      0.4215     1
# 1  NaN  NaN      0.0000      0.0000     -0.7239     0
# 2  NaN  NaN      0.0000      0.0000      0.4588     0
# 3  NaN  NaN      0.0000      0.0000      0.6805     0
# 4  NaN  NaN      0.4404      0.6808      0.9825     1
#
# [5 rows x 49 columns]

# %%
feature_cols=['index_score','desc1_score','desc2_score']
X = df[feature_cols] # Features
y = df.label # Target variable

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
print('Accuracy of GNB classifier on training set: {:.2f}'
     .format(gnb.score(X_train, y_train)))
print('Accuracy of GNB classifier on test set: {:.2f}'
     .format(gnb.score(X_test, y_test)))
# Out:
# Accuracy of GNB classifier on training set: 0.94
# Accuracy of GNB classifier on test set: 0.94

# %%
y_pred = gnb.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[92  0]
#  [ 7 22]]
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        92
#            1       1.00      0.76      0.86        29
#
#     accuracy                           0.94       121
#    macro avg       0.96      0.88      0.91       121
# weighted avg       0.95      0.94      0.94       121

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.05785123966942149
# Mean Squared Error: 0.05785123966942149
# Root Mean Squared Error: 0.24052284646041733
